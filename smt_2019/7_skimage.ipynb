# %% [markdown]
# # SMT Python Seminar - Image processing
#
# * image processing with Scikit-image
#
# Image used: https://commons.wikimedia.org/wiki/File:Worm-WormWheel-gearbox.jpg

# %% [markdown]
# ## Enabling some magic

# %% [markdown]
# More on the Jupyter magic commands: https://alexsm.com/jupyter-notebook-ipython-magic/

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ## Imports

# %%
import numpy as np
from matplotlib import pyplot as plt

import skimage
from skimage.feature import canny

# %% [markdown]
# ## Scikit-image demo

# %%
im = skimage.io.imread('../data/Worm-WormWheel-gearbox.jpg')

# %%
_ = plt.imshow(im)
_ = plt.axis('off')

# %%
im.shape
# Out:
# (1203, 1746, 3)

# %%
plt.figure(figsize=(15, 4))

_ = plt.subplot(1, 3, 1)
_ = plt.imshow(im[:, :, 0], cmap='Reds', vmin=0, vmax=255)
_ = plt.axis('off')
_ = plt.title('Red')

_ = plt.subplot(1, 3, 2)
_ = plt.imshow(im[:, :, 1], cmap='Greens', vmin=0, vmax=255)
_ = plt.axis('off')
_ = plt.title('Green')

_ = plt.subplot(1, 3, 3)
_ = plt.imshow(im[:, :, 2], cmap='Blues', vmin=0, vmax=255)
_ = plt.axis('off')
_ = plt.title('Blue')

# %%
im_gray = skimage.color.rgb2gray(im)

_ = plt.imshow(im_gray, cmap='gray')
_ = plt.axis('off')

# %%
im_edges = canny(im_gray, sigma=3)

_ = plt.figure(figsize=(15, 10))
_ = plt.imshow(im_edges, cmap='gist_yarg')
